# %%
import build123d as bd

# %%
pts=[
    (-15,5),
    (-13,0),
    (0,0),
    (65,0),
    (65.0/2,100),
]
line = bd.Polyline(pts)
slot = bd.SlotArc(line, 7)
s = bd.extrude(slot, 77)

# %%
display(s)
# Out:
# Part at 0x1fae9a35f30, label(), #children(0)

# %%
bd.export_stl(s, "support.stl")
# Out:
# True
