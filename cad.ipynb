# %%
import build123d as bd
import gggears as gg
import pathlib

holes_diameter = 4
gripper_holes_distance = 15

class Gripper:
    def __init__(self):
        self.gripper_arm_joint_radius = 2
        self.gripper_height = 40
        self.gripper_length = 60
        self.top_depth = 59
        self.top_width = 70
        self.top_thickness = 4  
        self.motor_height = 15
        self.motor_width = 21
        self.motor_length = 28.5
        self.motor_shaft_radius = 2.3/2
        self.arm_gear_height = 15
        self.worm_height = 10
        self.arm_thickness = 5
        self.arm_gear_height = self.worm_height/2
        self.gear_module = 1

        self.wedge_height = self.top_thickness * 0.4
        self.back_height = self.gripper_height+self.top_thickness

        self.worm_gear = gg.HelicalGear(
                number_of_teeth=4, helix_angle=gg.PI / 2 * 0.75, height=self.worm_height, module=self.gear_module, backlash=0.1
        )

        self.arm_gear = gg.HelicalGear(
            number_of_teeth=15, helix_angle=gg.PI / 2 * 0.25, height=self.arm_gear_height, module=self.gear_module, backlash=0.1
        )

        self.worm_gear_arm_length = self.arm_gear.max_outside_radius

    def make_gripper_base(self):
        line = bd.ThreePointArc((0,0),(-self.gripper_length/2,self.gripper_length/2),(0,self.gripper_length))
        face = bd.SlotArc(line, self.arm_thickness)
        arm = bd.extrude(face, self.gripper_height)


        l = self.gripper_length
        h = self.gripper_height
        for i in range(3):
            arm -= bd.Pos(0, l, i *h/3 + h/12 ) * bd.Box(l*2,l, self.gripper_height/6 + 3)

        r = self.gripper_arm_joint_radius
        arm += bd.Cylinder(r, self.top_thickness*2)
        arm += bd.Cylinder(r, self.top_thickness*2).translate((0, 0, self.gripper_height))
        return arm

    def make_gripper_left(self):
        arm = self.make_gripper_base()

        gear_part = self.arm_gear.build_part()
        arm += gear_part.translate((0,0, self.motor_height/2))
        
        return arm

    def make_gripper_right(self):
        arm = bd.Part() + self.make_gripper_base()
        arm = arm.rotate(bd.Axis.Y, 180).translate((0,0,self.gripper_height))


        gear_part = self.arm_gear.build_part()
        arm += gear_part.translate((0,0, self.motor_height/2))

        return arm
    
    def worm_drive(self):
        drive = bd.Part() + self.worm_gear.build_part()

        arm_shift = -self.worm_gear_arm_length/2 
        drive += bd.Cylinder(self.worm_gear.dedendum_radius, self.worm_gear_arm_length)\
                        .translate((0,0, arm_shift))
        
        drive -= bd.Cylinder(self.motor_shaft_radius, (self.worm_gear_arm_length+self.worm_height)*2)


        return drive

    def plate_wedge(self, length = None, tolerance_term = 0):
        if length is None:
            length = self.top_depth

        z = self.wedge_height / 2

        line = bd.Polyline([(
            -z-tolerance_term,-z),
            (z+tolerance_term,-z),
            (2*z+tolerance_term,z), 
            (-2*z-tolerance_term,z) ,
            (-z-tolerance_term,-z)
        ])
        
        face = bd.make_face(bd.Plane.XZ * line)
        wedge = bd.extrude(face, length)

        
        return wedge.translate((0,length/2,0))

    def holes_y_pos(self):
        return self.top_depth/2 - self.top_thickness - self.gripper_arm_joint_radius

    def plate_base(self):
        res = bd.Part() + bd.Box(self.top_width, self.top_depth, 4)
        holes_y_pos = self.holes_y_pos()
        hole_translate = self.arm_gear.pitch_radius + self.worm_gear.pitch_radius
        r = self.gripper_arm_joint_radius * 1.1
        res -= bd.Cylinder(r, self.top_thickness).translate((hole_translate, holes_y_pos, 0))
        res -= bd.Cylinder(r, self.top_thickness).translate((-hole_translate, holes_y_pos, 0))
 
        tolerance_term = 0.3
        w = self.plate_wedge(tolerance_term=tolerance_term)

        wedge_z_translate = -self.top_thickness/2 + self.wedge_height/2

        wedge_trans = self.top_width/2  - self.top_thickness
        res -= w.translate((-wedge_trans , 0, wedge_z_translate))
        res -= w.translate((wedge_trans,0, wedge_z_translate)) 

        return res

    def back_shape(self, tollerance_term = 0):
        w = self.top_width/2*0.7 - self.top_thickness 
        l = bd.Polyline([
            (-w, 0),
            (w, 0)
        ])
        slot = bd.SlotArc(l, self.top_thickness + tollerance_term)

        
        res = bd.Part() + bd.extrude(slot, self.back_height)

        c = bd.Cylinder(holes_diameter/2, self.top_thickness*2).rotate(bd.Axis.X, 90).translate((0,0,self.back_height/2))

        res -= c.translate((-gripper_holes_distance/2,0,0))
        res -= c.translate((gripper_holes_distance/2,0,0))

        return res.translate((0, -self.top_depth/2 + self.top_thickness*2,0))
    

    def top_plate(self):
        res = bd.Part() + self.plate_base()
        res -= self.back_shape(tollerance_term=0.5).translate((0,0,-self.gripper_height))
        return res
    

    def motor_box(self):
        res = bd.Part()
        t = self.top_thickness/2
        h = self.motor_height
        res += bd.Box(self.motor_width+t, self.motor_length+t, h)
        res -= bd.Box(self.motor_width, self.motor_length, h)
        res -= bd.Box(self.motor_width/2, t, h).translate((0,self.motor_length/2,h/4))

        l = 5
        s = self.motor_width/2 + l/2 
        res += bd.Cylinder(2, l).rotate(bd.Axis.Y, 90).translate((-s,0,h/4))
        res += bd.Cylinder(2, l).rotate(bd.Axis.Y, 90).translate((s,0,h/4))

        return res.translate((0,0,h/2))


    def bottom_plate(self):
        res = bd.Part() + self.plate_base().rotate(bd.Axis.Y, 180)
        y_shift = self.holes_y_pos() - self.motor_length/2 - self.worm_gear_arm_length - self.worm_height/2
        res += self.motor_box().translate((0, y_shift , 0))

        res += self.back_shape().translate((0,0,self.top_thickness/2))

        return res
    
    def side(self):
        side = bd.Part() + bd.Box(self.top_thickness, self.top_depth * 0.80, self.gripper_height)

        side += (
            self.plate_wedge(length=self.top_depth*0.80)
            .translate((0,0,self.gripper_height/2+self.wedge_height/2))
        )

        side += (
            self.plate_wedge(length=self.top_depth*0.80)
            .rotate(bd.Axis.Y, 180)
            .translate((0,0,-self.gripper_height/2-self.wedge_height/2))
        )

        return side
    
    def export_parts(self, folder = "."):
        path = pathlib.Path(folder)
        
        gripper_left = self.make_gripper_left()
        gripper_right = self.make_gripper_right()
        gripper_top = self.top_plate().rotate(bd.Axis.Y, 180)
        gripper_bottom = self.bottom_plate()
        gripper_side = self.side().rotate(bd.Axis.Y, 90)
        worm_drive = self.worm_drive().rotate(bd.Axis.Y, 180)

        bd.export_stl(gripper_left, path / "gripper_left.stl")
        bd.export_stl(gripper_right, path / "gripper_right.stl")
        bd.export_stl(gripper_top, path / "gripper_top.stl")
        bd.export_stl(gripper_bottom, path / "gripper_bottom.stl")
        bd.export_stl(gripper_side, path / "gripper_side.stl")
        bd.export_stl(worm_drive, path / "worm_drive.stl")


def main_arm():
    main_arm_length = 200
    arm_thickness = 5
    res = bd.Part()

    res += bd.Box(main_arm_length, arm_thickness, 15)

    connection_loc = bd.Rot(bd.Axis.X, 90) * bd.Pos((-main_arm_length/2, 0, 0))

    res += connection_loc * bd.Cylinder(20, arm_thickness)
    res -= connection_loc * bd.Cylinder(6/2, arm_thickness)

    hexagon = bd.RegularPolygon(25.5/2, 6)
    for v in hexagon.vertices():
        res -= connection_loc * bd.Pos(v) * bd.Cylinder(1.5, 20)
    

    gripper_connection = bd.Part() + bd.Box(5, gripper_holes_distance + holes_diameter*4 ,15)
    gripper_connection -= bd.Cylinder(holes_diameter/2, 15).rotate(bd.Axis.Y,90).translate((0, -gripper_holes_distance/2, 0))
    gripper_connection -= bd.Cylinder(holes_diameter/2, 15).rotate(bd.Axis.Y,90).translate((0, gripper_holes_distance/2, 0))

    res += gripper_connection.translate((main_arm_length/2, 0, 0))

    return res

def arm_base():
    thickness = 5
    side_height = 35
    base_width = 20
    motor_width = 42
    motor_height = 21 
    base_length = 70

    res = bd.Part()

    res += bd.Box(base_length, thickness, side_height)
    res -= bd.Box(motor_width, thickness, motor_height)

    support = bd.Rectangle(motor_width+8, 10).translate((0, 0, -10/2)).rotate(bd.Axis.X, 90)
    #res += bd.extrude(support, 90)
    for v in support.vertices():
        res -= bd.Pos(v) * bd.Cylinder(4/2, 30).rotate(bd.Axis.X, 90)
    
    base = bd.Part() +bd.Box(base_length, base_width, thickness)

    base_holes_shift = base_length/2 - 8
    base -= bd.Cylinder(3, thickness).translate((base_holes_shift,2,0))
    base -= bd.Cylinder(3, thickness).translate((-base_holes_shift,2,0))

    res += base.translate((0, base_width/2-thickness/2, -side_height/2-thickness/2))

    return res    

grp = Gripper()

def export_parts(folder = "."):
    path = pathlib.Path(folder)
    bd.export_stl(main_arm(), path / "main_arm.stl")
    bd.export_stl(arm_base(), path / "arm_base.stl")
    grp.export_parts(path)

# %%
display(arm_base())
# Out:
# <div id=shape-e67ca4f5></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(main_arm())
# Out:
# <div id=shape-bb9f7e8f></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(grp.side())
# Out:
# <div id=shape-bc8ed50c></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(grp.bottom_plate())
# Out:
# <div id=shape-9c6e2644></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(grp.top_plate())
# Out:
# Compound at 0x23e7c867890, label(), #children(0)

# %%
display(grp.make_gripper_left())
# Out:
# <div id=shape-ece997c3></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(grp.make_gripper_right())
# Out:
# <div id=shape-56ecce17></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
display(grp.worm_drive())
# Out:
# <div id=shape-1ef573ca></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
res = bd.Part() 
res += grp.arm_gear.build_part()
r1 = grp.arm_gear.pitch_radius
r2 = grp.worm_gear.pitch_radius
res += grp.worm_gear.build_part().rotate(bd.Axis.Y, 90).translate((0,r1+r2,0))
display(res)
# Out:
# <div id=shape-fc01b01b></div><script>function render(data, div_id, ratio){
#
#     // Initial setup
#     const renderWindow = vtk.Rendering.Core.vtkRenderWindow.newInstance();
#     const renderer = vtk.Rendering.Core.vtkRenderer.newInstance({ background: [1, 1, 1 ] });
#     renderWindow.addRenderer(renderer);
#
#     // iterate over all children children
#     for (var el of data){
#         var trans = el.position;
#         var rot = el.orientation;
#         var rgba = el.color;
#         var shape = el.shape;
#
#         // load the inline data
#         var reader = vtk.IO.XML.vtkXMLPolyDataReader.newInstance();
#         const textEncoder = new TextEncoder();
#         reader.parseAsArrayBuffer(textEncoder.encode(shape));
#
#         // setup actor,mapper and add
#         const mapper = vtk.Rendering.Core.vtkMapper.newInstance();
#         mapper.setInputConnection(reader.getOutputPort());
#         mapper.setResolveCoincidentTopologyToPolygonOffset();
# ...

# %%
export_parts("parts")
